# %%
#<aside>
💡 **Q1.** Given an array of integers nums and an integer target, return indices of the two numbers such that they add up to
    target.

You may assume that each input would have exactly one solution, and you may not use the same element twice.

You can return the answer in any order.

**Example:**
Input: nums = [2,7,11,15], target = 9
Output0 [0,1]

**Explanation:** Because nums[0] + nums[1] == 9, we return [0, 1][

</aside>
  
"""To find the indices of two numbers in an array that add up to a given target, you can use a two-pointer approach. 
   Here's the solution in Python:
"""    
    
def twoSum(nums, target):
    num_map = {}  # Map to store the numbers and their indices

    # Iterate through the array
    for i, num in enumerate(nums):
        complement = target - num

        # Check if the complement exists in the map
        if complement in num_map:
            return [num_map[complement], i]  # Return the indices

        # Add the number to the map with its index
        num_map[num] = i

    # If no solution is found, return an empty list or handle it as needed
    return []

# Example usage
nums = [2, 7, 11, 15]
target = 9
result = twoSum(nums, target)
print(result)  # Output: [0, 1]
# Out:
# [0, 1]

# %%
"""The algorithm maintains a map (num_map) where each number in the array is mapped to its index. It iterates through the
   array and for each number, it computes the complement (the difference between the target and the current number). If the
  complement exists in the map, it means that the two numbers add up to the target, so it returns the indices. Otherwise,
  it adds the number to the map and continues. If no solution is found, it returns an empty list (or you can handle it 
  differently based on your needs)."""

# %%
#<aside>
💡 **Q2.** Given an integer array nums and an integer val, remove all occurrences of val in nums in-place. The order of 
         the elements may be changed. Then return the number of elements in nums which are not equal to val.

   Consider the number of elements in nums which are not equal to val be k, to get accepted, you need to do the following 
    things:

- Change the array nums such that the first k elements of nums contain the elements which are not equal to val. The 
   remaining elements of nums are not important as well as the size of nums.
- Return k.

**Example :**
Input: nums = [3,2,2,3], val = 3
Output: 2, nums = [2,2,_*,_*]

**Explanation:** Your function should return k = 2, with the first two elements of nums being 2. It does not matter what 
you leave beyond the returned k (hence they are underscores)[

</aside>
    
"""To remove all occurrences of a given value from an integer array nums in-place and return the number of elements that 
   are not equal to the value, you can use a two-pointer approach. Here's the solution in Python:"""

def removeElement(nums, val):
    k = 0  # Number of elements not equal to val

    # Iterate through the array
    for i in range(len(nums)):
        if nums[i] != val:
            nums[k] = nums[i]
            k += 1

    return k

# Example usage
nums = [3, 2, 2, 3]
val = 3
k = removeElement(nums, val)
print(k)  # Output: 2
print(nums)  # Output: [2, 2, _, _]
# Out:
# 2
# [2, 2, 2, 3]

# %%
"""The algorithm uses two pointers: i to iterate through the array and k to keep track of the next index to store elements 
   not equal to val. Whenever nums[i] is not equal to val, it means it's one of the elements we want to keep. We store it at
   index k and increment k by 1. After iterating through the entire array, the first k elements will contain the elements not
   equal to val. The remaining elements are not important and can be ignored. The algorithm returns k, which represents the
   number of elements not equal to val.
   
   
   Note: In the example output provided, underscores (_) are used to represent the remaining elements of nums beyond the 
   returned k. However, in reality, the values of those elements remain unchanged, and only the first k elements are
   meaningful."""

# %%
#<aside>
💡 **Q3.** Given a sorted array of distinct integers and a target value, return the index if the target is found. If not,
    return the index where it would be if it were inserted in order.

You must write an algorithm with O(log n) runtime complexity.

**Example 1:**
Input: nums = [1,3,5,6], target = 5

Output: 2

</aside>

"""To solve this problem with O(log n) runtime complexity, we can use the binary search algorithm. Here's the algorithm 
   to find the index of the target value or the index where it would be inserted:
   
     1. Initialize two pointers, left and right, pointing to the start and end of the array respectively.
     
     2. While left is less than or equal to right, do:
        a. Calculate the middle index as mid = (left + right) / 2.
        b. If the value at the middle index is equal to the target, return the middle index.
        c. If the value at the middle index is greater than the target, update right = mid - 1.
        d. If the value at the middle index is less than the target, update left = mid + 1.
        
     3. If the target is not found in the array, the value of left will represent the index where it should be inserted.
       Return left.
       
 Here's the implementation in Python:"""

def searchInsert(nums, target):
    left, right = 0, len(nums) - 1

    while left <= right:
        mid = (left + right) // 2
        if nums[mid] == target:
            return mid
        elif nums[mid] < target:
            left = mid + 1
        else:
            right = mid - 1

    return left
# Out:
#   File <tokenize>:15
#     nums = [1, 3, 5, 6]
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
"""Let's test the example given:
"""
nums = [1, 3, 5, 6]
target = 5

print(searchInsert(nums, target))
# Out:
# 2

# %%
"""The target value 5 is found at index 2 in the given array."""

# %%
#<aside>
💡 **Q4.** You are given a large integer represented as an integer array digits, where each digits[i] is the ith digit of 
   the integer. The digits are ordered from most significant to least significant in left-to-right order. The large integer 
    does not contain any leading 0's.

Increment the large integer by one and return the resulting array of digits.

**Example 1:**
Input: digits = [1,2,3]
Output: [1,2,4]

**Explanation:** The array represents the integer 123.

Incrementing by one gives 123 + 1 = 124.
Thus, the result should be [1,2,4].

</aside>

"""To increment a large integer represented as an array of digits by one, we need to consider the carry-over operation 
   when adding one to the least significant digit. Here's the algorithm to perform this operation:
   
     1. Start from the least significant digit and iterate backwards through the array.
     
     2. Add one to the current digit.
     
     3. If the result is less than 10 (no carry-over), update the digit in the array and return the updated array.
     
     4. If the result is 10 or greater (carry-over), update the current digit to the remainder of the division by 10, and 
        continue the iteration.
        
    5. If the iteration reaches the most significant digit and a carry-over is still needed, insert 1 at the beginning
      of the array.
      
    6. Return the updated array. 
    
    
  Here's the implementation in Python:"""

def plusOne(digits):
    n = len(digits)
    for i in range(n - 1, -1, -1):
        digits[i] += 1
        if digits[i] < 10:
            return digits
        digits[i] %= 10

    digits.insert(0, 1)
    return digits

# %%
def plusOne(digits):
    n = len(digits)
    for i in range(n - 1, -1, -1):
        digits[i] += 1
        if digits[i] < 10:
            return digits
        digits[i] %= 10

    digits.insert(0, 1)
    return digits


digits = [1, 2, 3]
result = plusOne(digits)
print(result)  # Output: [1, 2, 4]
# Out:
# [1, 2, 4]

# %%
"""The array [1, 2, 3] represents the integer 123. Incrementing by one gives 123 + 1 = 124, which corresponds to the
   array [1, 2, 4]."""

# %%
#<aside>
💡 **Q5.** You are given two integer arrays nums1 and nums2, sorted in non-decreasing order, and two integers m and n,
    representing the number of elements in nums1 and nums2 respectively.

Merge nums1 and nums2 into a single array sorted in non-decreasing order.

The final sorted array should not be returned by the function, but instead be stored inside the array nums1. To accommodate 
this, nums1 has a length of m + n, where the first m elements denote the elements that should be merged, and the last n 
elements are set to 0 and should be ignored. nums2 has a length of n.

**Example 1:**
Input: nums1 = [1,2,3,0,0,0], m = 3, nums2 = [2,5,6], n = 3
Output: [1,2,2,3,5,6]

**Explanation:** The arrays we are merging are [1,2,3] and [2,5,6].
The result of the merge is [1,2,2,3,5,6] with the underlined elements coming from nums1.

</aside>

"""To merge the two sorted arrays nums1 and nums2 into a single array sorted in non-decreasing order, you can use the 
   following approach:
   
     1. Initialize three pointers:

       . p1 to track the current element in nums1 (starting from the last non-zero element in nums1).
       . p2 to track the current element in nums2 (starting from the last element in nums2).
       . p to track the current position in the merged array nums1 (starting from the last position of nums1).
       
     2. Iterate while p1 and p2 are within their respective arrays:

       . If nums1[p1] is greater than nums2[p2], set nums1[p] to nums1[p1] and decrement p1 and p.
       . Otherwise, set nums1[p] to nums2[p2] and decrement p2 and p.   
       
     3. After the above iteration, if there are remaining elements in nums2, they need to be copied to the beginning of 
       nums1. Iterate over p2 and copy the remaining elements to nums1 starting from index 0 until p2 becomes -1."""

 Here's the implementation in Python:

# %%
def merge(nums1, m, nums2, n):
    p1 = m - 1
    p2 = n - 1
    p = m + n - 1
    
    while p1 >= 0 and p2 >= 0:
        if nums1[p1] > nums2[p2]:
            nums1[p] = nums1[p1]
            p1 -= 1
        else:
            nums1[p] = nums2[p2]
            p2 -= 1
        p -= 1
    
    while p2 >= 0:
        nums1[p] = nums2[p2]
        p2 -= 1
        p -= 1
#You can call the merge function with the given inputs like this:
        
    nums1 = [1, 2, 3, 0, 0, 0]
m = 3
nums2 = [2, 5, 6]
n = 3

merge(nums1, m, nums2, n)
print(nums1)  # Output: [1, 2, 2, 3, 5, 6]
# Out:
# [1, 2, 2, 3, 5, 6]

# %%
"""After merging, the sorted array is stored within nums1 as [1, 2, 2, 3, 5, 6]."""

# %%
#<aside>
💡 **Q6.** Given an integer array nums, return true if any value appears at least twice in the array, and return false 
if every element is distinct.

**Example 1:**
Input: nums = [1,2,3,1]

Output: true

</aside>

"""To determine if any value appears at least twice in the given integer array nums, you can use a hash set to keep track of 
   the elements you have encountered so far."""


# Here's the Python code that implements this approach:

def containsDuplicate(nums):
    seen = set()
    for num in nums:
        if num in seen:
            return True
        seen.add(num)
    return False

"""In this code, we iterate over each element num in the array nums. If num is already present in the seen set, it means we
   have encountered it before and it is a duplicate. In that case, we return True. Otherwise, we add num to the seen set and 
   continue to the next element. If we reach the end of the loop without finding any duplicates, we return False.

  Using this approach, the code will return True for the example input [1,2,3,1] because the value 1 appears twice in
  the array."""

# %%
#<aside>
💡 **Q7.** Given an integer array nums, move all 0's to the end of it while maintaining the relative order of the nonzero
    elements.

Note that you must do this in-place without making a copy of the array.

**Example 1:**
Input: nums = [0,1,0,3,12]
Output: [1,3,12,0,0]

</aside>

"""To move all zeros to the end of the integer array nums while maintaining the relative order of the non-zero elements,
   you can use a two-pointer approach."""

#Here's the Python code that implements this approach:

def moveZeroes(nums):
    n = len(nums)
    zero_ptr = 0  # Pointer to keep track of the position to swap zeros
    for i in range(n):
        if nums[i] != 0:
            # Swap the non-zero element with the position pointed by zero_ptr
            nums[i], nums[zero_ptr] = nums[zero_ptr], nums[i]
            zero_ptr += 1

"""In this code, we initialize a variable zero_ptr to keep track of the position where the next zero should be placed. 
   We iterate through the array using the i pointer. If the element at nums[i] is non-zero, we swap it with the element 
   at nums[zero_ptr], and then increment zero_ptr by 1. This ensures that non-zero elements are moved towards the beginning 
   of the array, while zeros are pushed towards the end.

   Using this approach, the code will transform the example input [0,1,0,3,12] into [1,3,12,0,0], as required."""

# %%
#<aside>
💡 **Q8.** You have a set of integers s, which originally contains all the numbers from 1 to n. Unfortunately, due to some
    error, one of the numbers in s got duplicated to another number in the set, which results in repetition of one number 
    and loss of another number.

You are given an integer array nums representing the data status of this set after the error.

Find the number that occurs twice and the number that is missing and return them in the form of an array.

**Example 1:**
Input: nums = [1,2,2,4]
Output: [2,3]

</aside>

"""To find the number that occurs twice and the number that is missing in the given integer array nums, you can use a 
   combination of two approaches: sorting and hashing."""

#Here's the Python code that implements this approach:

def findErrorNums(nums):
    n = len(nums)
    duplicate = -1
    missing = -1

    # Sort the array
    nums.sort()

    # Find the duplicate and missing numbers
    for i in range(1, n):
        if nums[i] == nums[i-1]:
            duplicate = nums[i]
        elif nums[i] > nums[i-1] + 1:
            missing = nums[i-1] + 1

    # Check if the missing number is at the beginning or end
    if nums[0] != 1:
        missing = 1
    elif nums[n-1] != n:
        missing = n

    return [duplicate, missing]

"""In this code, we first sort the array nums in ascending order. Then, we iterate through the sorted array and compare
   adjacent elements. If we find a pair of adjacent elements that are equal, it means we have found the duplicate number. 
   If we find a pair of adjacent elements with a gap of more than 1, it means we have found the missing number. We also
   check if the missing number is at the beginning or end of the sorted array.

  Using this approach, the code will return [2, 3] for the example input [1, 2, 2, 4], indicating that 2 is the duplicate
  number and 3 is the missing number."""
